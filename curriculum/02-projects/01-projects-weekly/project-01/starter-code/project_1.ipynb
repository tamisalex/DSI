# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# The data contains Rate of Participation, Math scores, and Verbal Scores for the SAT categorized by state/district.

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# The data looks complete, Nebraska has the wrong two letter combination. It should NE, not NB

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
import csv
rows = []
with open ("../assets/sat_scores.csv", 'r') as f:
    reader = csv.reader(f)
    rows = map(lambda x: x,reader)

# %% [markdown]
# ##### 5. Print the data

# %%
print rows
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '
# ...

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
headers = rows[0]
print headers
rows = rows[1:]
print rows
# Out:
# ['State', 'Rate', 'Verbal', 'Math']
# ...

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
states = []
for i in rows:
    states.append(i[0])
print states
# Out:
# ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NB', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
for i in rows[0]:
    print type(i).__name__
# Out:
# str
# str
# str
# str

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
for i in rows:
    i[1] = int(i[1])
    i[2] = int(i[2])
    i[3] = int(i[3])
    
print rows
# Out:
# [['CT', 82, 509, 510], ['NJ', 81, 499, 513], ['MA', 79, 511, 515], ['NY', 77, 495, 505], ['NH', 72, 520, 516], ['RI', 71, 501, 499], ['PA', 71, 500, 499], ['VT', 69, 511, 506], ['ME', 69, 506, 500], ['VA', 68, 510, 501], ['DE', 67, 501, 499], ['MD', 65, 508, 510], ['NC', 65, 493, 499], ['GA', 63, 491, 489], ['IN', 60, 499, 501], ['SC', 57, 486, 488], ['DC', 56, 482, 474], ['OR', 55, 526, 526], ['FL', 54, 498, 499], ['WA', 53, 527, 527], ['TX', 53, 493, 499], ['HI', 52, 485, 515], ['AK', 51, 514, 510], ['CA', 51, 498, 517], ['AZ', 34, 523, 525], ['NV', 33, 509, 515], ['CO', 31, 539, 542], ['OH', 26, 534, 439], ['MT', 23, 539, 539], ['WV', 18, 527, 512], ['ID', 17, 543, 542], ['TN', 13, 562, 553], ['NM', 13, 551, 542], ['IL', 12, 576, 589], ['KY', 12, 550, 550], ['WY', 11, 547, 545], ['MI', 11, 561, 572], ['MN', 9, 580, 589], ['KS', 9, 577, 580], ['AL', 9, 559, 554], ['NB', 8, 562, 568], ['OK', 8, 567, 561], ['MO', 8, 577, 577], ['LA', 7, 564, 562], ['WI', 6, 584, 596], ['AR', 6, 562, 
# ...

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
Rates = {}
Verbal = {}
Math = {}
for item in rows:
    Rates[item[0]] = item[1]
    Verbal[item[0]] = item[2]
    Math[item[0]] = item[3]
    
Rates
# Out:
# {'AK': 51,
#  'AL': 9,
#  'AR': 6,
#  'AZ': 34,
#  'CA': 51,
#  'CO': 31,
#  'CT': 82,
#  'DC': 56,
#  'DE': 67,
#  'FL': 54,
#  'GA': 63,
#  'HI': 52,
#  'IA': 5,
#  'ID': 17,
#  'IL': 12,
#  'IN': 60,
#  'KS': 9,
#  'KY': 12,
#  'LA': 7,
#  'MA': 79,
#  'MD': 65,
#  'ME': 69,
#  'MI': 11,
#  'MN': 9,
#  'MO': 8,
#  'MS': 4,
#  'MT': 23,
#  'NB': 8,
#  'NC': 65,
#  'ND': 4,
#  'NH': 72,
#  'NJ': 81,
#  'NM': 13,
#  'NV': 33,
#  'NY': 77,
#  'OH': 26,
#  'OK': 8,
#  'OR': 55,
#  'PA': 71,
#  'RI': 71,
#  'SC': 57,
#  'SD': 4,
#  'TN': 13,
#  'TX': 53,
#  'UT': 5,
#  'VA': 68,
#  'VT': 69,
#  'WA': 53,
#  'WI': 6,
#  'WV': 18,
#  'WY': 11}

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
print "Rates: %s" % Rates
print "Verbal: %s" % Verbal
print "Math: %s" % Math
# Out:
# Rates: {'WA': 53, 'DE': 67, 'DC': 56, 'WI': 6, 'WV': 18, 'HI': 52, 'FL': 54, 'WY': 11, 'NH': 72, 'NJ': 81, 'NM': 13, 'TX': 53, 'LA': 7, 'NB': 8, 'NC': 65, 'ND': 4, 'TN': 13, 'NY': 77, 'PA': 71, 'RI': 71, 'NV': 33, 'VA': 68, 'CO': 31, 'AK': 51, 'AL': 9, 'AR': 6, 'VT': 69, 'IL': 12, 'GA': 63, 'IN': 60, 'IA': 5, 'OK': 8, 'AZ': 34, 'CA': 51, 'ID': 17, 'CT': 82, 'ME': 69, 'MD': 65, 'MA': 79, 'OH': 26, 'UT': 5, 'MO': 8, 'MN': 9, 'MI': 11, 'KS': 9, 'MT': 23, 'MS': 4, 'SC': 57, 'KY': 12, 'OR': 55, 'SD': 4}
# ...

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../assets/sat_scores.csv")
for i in data.columns.values[1:]:
    print "Max of %s: %f" % (i,np.max(data.ix[0:len(data.index-1),i]))
    print "Min of %s: %f" % (i,np.min(data.ix[0:len(data.index-1),i]))
# Out:
# Max of Rate: 82.000000
# Min of Rate: 4.000000
# Max of Verbal: 593.000000
# Min of Verbal: 482.000000
# Max of Math: 603.000000
# Min of Math: 439.000000

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
def PrintStd(data,columnName):
    print "Std of %s: %d " % (columnName,np.std(data.ix[0:len(data.index - 1),columnName]))

[PrintStd(data, x) for x in data.columns.values[1:].tolist()]

#JB your last line is a list comp, but you need to put the function inside
# Out:
# Std of Rate: 27
# Std of Verbal: 33
# Std of Math: 35
# [None, None, None]

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
import seaborn as sns

# %matplotlib inline

def distribution_plotter(column, data):
    sns.set(rc={"figure.figsize": (10, 7)})
    sns.set_style("white")
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    dist.set_title('Distribution of ' + column + '\n', fontsize=16)
    
distribution_plotter(data.columns.values[1],data.iloc[:,1:2])

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
distribution_plotter(data.columns.values[3],data.ix[1:,"Math"])

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
distribution_plotter(data.columns.values[2],data.ix[1:,"Verbal"])

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# we usually expect a normal distribution

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# No, score distributions for Rate and Verbal are bimodal, and Math is between bimodal and a normal distribution
#
# #JB great!

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
import matplotlib.pyplot as plt

rate = data.ix[1:,"Rate"].values
x = data.ix[1:,"Verbal"].values
y = data.ix[1:,"Math"].values

fig = plt.figure(figsize=(12,8))
plt.scatter(np.array(x), np.array(rate))
#plt.axis([450,650,450,650])

axes = fig.gca()
axes.set_title('Verbal vs Rate scores\n')
axes.set_xlabel('Math Scores')
axes.set_ylabel('Rate')
#axes.set_autoscale_on(False)

plt.show

fig2 = plt.figure(figsize=(12,8))
plt.scatter(np.array(y), np.array(rate))
#plt.axis([450,650,450,650])

axes2 = fig.gca()
axes2.set_title('Math vs Rate scores\n')
axes2.set_xlabel('Verbal Scores')
axes2.set_ylabel('Rate')
#axes.set_autoscale_on(False)

plt.show()

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# the less participation rate has the higher the score

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
#help(sns.boxplot)

ax = sns.boxplot(data=data.ix[1:,2:])
ax.set_title('Box Plot of Math and Verbal Scores')
ax.set_xlabel('Scores')

ax2 = sns.boxplot(data=data.ix[1:,1:2])
ax2.set_title('Box Plot of Rate of Score')
ax2.set_xlabel('Scores')

#JB build two separate plots because y-axis is different

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %%
from IPython.display import Image
Image(filename='../assets/Verbal Dashboard.png')

# %%
Image(filename='../assets/Math Dashboard.png')

# %%
Image(filename='../assets/Rate Dashboard.png')

# %% [markdown]
# Score: 9/10
# Identify: Discuss Data:3
# Acquire: Load Data with Python:2
# Present: Visualize Data:3
# Bonus: Use Tableau:1
